# %%
from Preprocesamiento.lematizador import lematizar
import os, pickle
import pandas as pd
# Out:
# FREELINGDIR environment variable not defined, trying  /usr

# %%
def load_corpus(corpus):
    corpus_lematizado = []
    
    corpus = corpus.replace('(','').replace(')','')
    
    for linea in corpus.split():
        corpus_lematizado.append(lematizar(linea))
        print(corpus_lematizado)
        return(corpus_lematizado)

# %%
if __name__ == "__main__":
	corpus = pd.read_excel("REST.xlsx", index_col=None)
	corpus_lematizado = []

	#Load lexicons
	if (os.path.exists('corpus_lematizado.pkl')):
		corpus_file = open ('corpus_lematizado.pkl','rb')
		corpus_lematizado = pickle.load(corpus_file)
	else:
            for linea in range(len(corpus)):
                corpus_lematizado.append(load_corpus(str(corpus.loc[linea]["Title"]) + " " + str(corpus.loc[linea]["Opinion"])))
                print("-------------")
            corpus_file = open('corpus_lematizado.pkl','wb')
            pickle.dump(corpus_lematizado, corpus_file)
            corpus_file.close()

#print (corpus_lematizado)
# Out:
# ['malo  ']
# -------------
# ['no  ']
# -------------
# ['malo  ']
# -------------
# ['minusválido ?  ']
# -------------
# ['ser  ']
# -------------
# ['el  ']
# -------------
# ['definitivamente  ']
# -------------
# ['terrible  ']
# -------------
# ['bebida  ']
# -------------
# ['hotel  ']
# -------------
# ['el  ']
# -------------
# ['el  ']
# -------------
# ['ser  ']
# -------------
# ['muy  ']
# -------------
# ['malo  ']
# -------------
# ['tener  ']
# -------------
# ['decepcionar  ']
# -------------
# ['no  ']
# -------------
# ['no  ']
# -------------
# ['uno  ']
# -------------
# ['muy  ']
# -------------
# ['joyería  ']
# -------------
# ['secuestro  ']
# -------------
# ['para  ']
# -------------
# ['¿ qué  ']
# -------------
# ['no  ']
# -------------
# ['muy  ']
# -------------
# ['peor  ']
# -------------
# ['sinvergüenza ! !  ']
# -------------
# ['¡ no  ']
# -------------
# ['boda  ']
# -------------
# ['malo  ']
# -------------
# ['timo  ']
# -------------
# ['no  ']
# -------------
# ['servicio  ']
# -------------
# ['servicio  ']
# -------------
# ['vacaciones  ']
# -------------
# ['genial ,  ']
# -------------
# ['malo  ']
# -------------
# ['malo  ']
# -------------
# ['malo  ']
# -------------
# ['malo  ']
# -------------
# ['evitar  ']
# -------------
# ['desayuno  ']
# -------------
# ['fatal  ']
# -------------
# ['horrible  ']
# -------------
# ['timo  ']
# -------------
# ['bonito  ']
# -------------
# ['nunca  ']
# -------------
# ['no  ']
# -------------
# ['caro  ']
# -------------
# ['decepcionante  ']
# -------------
# ['llegar  ']
# -------------
# ['de el  ']
# -------------
# ['decepcionar  ']
# -------------
# ['no  ']
# -------------
# ['no  ']
# -------------
# ['malo  ']
# -------------
# ['haber  ']
# -------------
# ['engaño  ']
# -------------
# ['ni  ']
# -------------
# ['malo  ']
# -------------
# ['peor  ']
# -------------
# ['muy  ']
# -------------
# ['malo  ']
# -------------
# ['uno  ']
# -------------
# ['no  ']
# -------------
# ['cucaracha  ']
# -------------
# ['malo  ']
# -------------
# ['malo . ']
# -------------
# ['cuidado  ']
# -------------
# ['nunca  ']
# -------------
# ['no  ']
# -------------
# ['peor  ']
# -------------
# ['el  ']
# -------------
# ['decepcionante ,  ']
# -------------
# ['experiencia  ']
# -------------
# ['hotel  ']
# -------------
# ['mediocre  ']
# -------------
# ['comida  ']
# -------------
# ['no  ']
# -------------
# ['malo  ']
# -------------
# ['decepción  ']
# -------------
# ['cucaracha  ']
# -------------
# ['el  ']
# -------------
# ['no  ']
# -------------
# ['vacaciones  ']
# -------------
# ['ni  ']
# -------------
# ['el  ']
# -------------
# ['pesimo  ']
# -------------
# ['muy  ']
# -------------
# ['terrible  ']
# -------------
# ['el  ']
# -------------
# ['huésped  ']
# -------------
# ['servicio  ']
# -------------
# ['outrageouly  ']
# -------------
# ['excelente  ']
# -------------
# ['espantoso  ']
# -------------
# ['cerrar  ']
# -------------
# ['malo  ']
# -------------
# ['no  ']
# -------------
# ['uno  ']
# -------------
# ['muy  ']
# -------------
# ['para  ']
# -------------
# ['1  ']
# -------------
# ['mal  ']
# -------------
# ['si  ']
# -------------
# ['ni  ']
# -------------
# ['también  ']
# -------------
# ['totalmente  ']
# -------------
# ['grupal  ']
# -------------
# ['pesima  ']
# -------------
# ['malo  ']
# -------------
# ['malo  ']
# -------------
# ['igual  ']
# -------------
# ['decepcionar  ']
# -------------
# ['muy  ']
# -------------
# ['tratamiento  ']
# -------------
# ['precioso ,  ']
# -------------
# ['sin  ']
# -------------
# ['😠  ']
# -------------
# ['horrible  ']
# -------------
# ['evitar  ']
# -------------
# ['atención  ']
# -------------
# ['uno  ']
# -------------
# ['decepcionar  ']
# -------------
# ['mi  ']
# -------------
# ['inicio  ']
# -------------
# ['haber  ']
# -------------
# ['el  ']
# -------------
# ['malo  ']
# -------------
# ['experiencia  ']
# -------------
# ['el  ']
# -------------
# ['multipropiedad  ']
# -------------
# ['malo  ']
# -------------
# ['camida  ']
# -------------
# ['dolor  ']
# -------------
# ['terrible  ']
# -------------
# ['nada  ']
# -------------
# ['alberca  ']
# -------------
# ['alejar  ']
# -------------
# ['el  ']
# -------------
# ['no  ']
# -------------
# ['booourns  ']
# -------------
# ['pesimo . ']
# -------------
# ['gran  ']
# -------------
# ['engañoso  ']
# -------------
# ['malo  ']
# -------------
# ['fraude  ']
# -------------
# ['uno  ']
# -------------
# ['actitud  ']
# -------------
# ['no  ']
# -------------
# ['5  ']
# -------------
# ['no  ']
# -------------
# ['el  ']
# -------------
# ['falta  ']
# -------------
# ['no  ']
# -------------
# ['malo  ']
# -------------
# ['malo  ']
# -------------
# ['horrible  ']
# -------------
# ['cena  ']
# -------------
# ['estar  ']
# -------------
# ['terrible  ']
# -------------
# ['falta  ']
# -------------
# ['. ']
# -------------
# ['gran  ']
# -------------
# ['estar  ']
# -------------
# ['malo  ']
# -------------
# ['malo  ']
# -------------
# ['precioso  ']
# -------------
# ['caro  ']
# -------------
# ['tener  ']
# -------------
# ['grandluxxe  ']
# -------------
# ['sacar  ']
# -------------
# ['sin  ']
# -------------
# ['restaurante  ']
# -------------
# ['sin  ']
# -------------
# ['gran  ']
# -------------
# ['no  ']
# -------------
# ['no  ']
# -------------
# ['hotel  ']
# -------------
# ['']
# -------------
# ['ten_miel  ']
# -------------
# ['peor  ']
# -------------
# ['no  ']
# -------------
# ['peor  ']
# -------------
# ['horrible  ']
# -------------
# ['el  ']
# -------------
# ['el  ']
# -------------
# ['interesante  ']
# -------------
# ['el  ']
# -------------
# ['el  ']
# -------------
# ['sin  ']
# -------------
# ['fyi  ']
# -------------
# ['vacaciones  ']
# -------------
# ['malo  ']
# -------------
# ['peor  ']
# -------------
# ['malo  ']
# -------------
# ['preparir  ']
# -------------
# ['estar  ']
# -------------
# ['muy  ']
# -------------
# ['no  ']
# -------------
# ['servicio  ']
# -------------
# ['no  ']
# -------------
# ['malo  ']
# -------------
# ['el  ']
# -------------
# ['uno  ']
# -------------
# ['2016-12-01  ']
# -------------
# ['ser  ']
# -------------
# ['ser  ']
# -------------
# ['malo  ']
# -------------
# ['¡ alerta ,  ']
# -------------
# ['gran  ']
# -------------
# ['el  ']
# -------------
# ['malo  ']
# -------------
# ['no  ']
# -------------
# ['peor  ']
# -------------
# ['moho  ']
# -------------
# ['no  ']
# -------------
# ['sorprender  ']
# -------------
# ['ex-agente  ']
# -------------
# ['malo  ']
# -------------
# ['evitar  ']
# -------------
# ['malo  ']
# -------------
# ['muy  ']
# -------------
# ['cena  ']
# -------------
# ['malo  ']
# -------------
# ['lamentable  ']
# -------------
# ['vacaciones  ']
# -------------
# ['si  ']
# -------------
# ['¡ uno  ']
# -------------
# ['gran  ']
# -------------
# ['']
# -------------
# ['']
# -------------
# ['ten a inoportuno  ']
# -------------
# ['estafa  ']
# -------------
# ['cada  ']
# -------------
# ['muy  ']
# -------------
# ['conseguir  ']
# -------------
# ['el  ']
# -------------
# ['regresar  ']
# -------------
# ['malo  ']
# -------------
# ['no  ']
# -------------
# ['muy  ']
# -------------
# ['mal  ']
# -------------
# ['servicio  ']
# -------------
# ['total  ']
# -------------
# ['caro  ']
# -------------
# ['decepcionante  ']
# -------------
# ['no  ']
# -------------
# ['lleno  ']
# -------------
# ['malo  ']
# -------------
# ['malisimo  ']
# -------------
# ['excesivamente  ']
# -------------
# ['el  ']
# -------------
# ['malo  ']
# -------------
# ['3  ']
# -------------
# ['servicio  ']
# -------------
# ['nadar  ']
# -------------
# ['malo  ']
# -------------
# ['cerradura  ']
# -------------
# ['no  ']
# -------------
# ['el  ']
# -------------
# ['']
# -------------
# ['ten pesimo  ']
# -------------
# ['malo  ']
# -------------
# ['no  ']
# -------------
# ['mugre  ']
# -------------
# ['mal  ']
# -------------
# ['6  ']
# -------------
# ['malo  ']
# -------------
# ['no  ']
# -------------
# ['malo  ']
# -------------
# ['me  ']
# -------------
# ['no  ']
# -------------
# ['el  ']
# -------------
# ['terrible  ']
# -------------
# ['malo  ']
# -------------
# ['evitar  ']
# -------------
# ['el  ']
# -------------
# ['espantoso  ']
# -------------
# ['muy  ']
# -------------
# ['ni  ']
# -------------
# ['necesidad  ']
# -------------
# ['the  ']
# -------------
# ['nunca  ']
# -------------
# ['no  ']
# -------------
# ['malo  ']
# -------------
# ['vacaciones  ']
# -------------
# ['malo  ']
# -------------
# ['el  ']
# -------------
# ['alejar  ']
# -------------
# ['malo  ']
# -------------
# ['no  ']
# -------------
# ['comida  ']
# -------------
# ['de  ']
# -------------
# ['gran  ']
# -------------
# ['no  ']
# -------------
# ['salir  ']
# -------------
# ['cuidado  ']
# -------------
# ['no  ']
# -------------
# ['moho  ']
# -------------
# ['comenzar  ']
# -------------
# ['mal  ']
# -------------
# ['prepotente  ']
# -------------
# ['excelente  ']
# -------------
# ['pesimo  ']
# -------------
# ['el  ']
# -------------
# ['no  ']
# -------------
# ['horror  ']
# -------------
# ['trampa  ']
# -------------
# ['extremadamente  ']
# -------------
# ['mal  ']
# -------------
# ['bad  ']
# -------------
# ['fallo  ']
# -------------
# ['no  ']
# -------------
# ['probar  ']
# -------------
# ['evitar  ']
# -------------
# ['uno  ']
# -------------
# ['no  ']
# -------------
# ['sin  ']
# -------------
# ['baja  ']
# -------------
# ['alojar  ']
# -------------
# ['decepción  ']
# -------------
# ['cucaracha ! ! !  ']
# -------------
# ['pesima  ']
# -------------
# ['grand  ']
# -------------
# ['excelente  ']
# -------------
# ['lastimar  ']
# -------------
# ['tratamiento  ']
# -------------
# ['malo  ']
# -------------
# ['hotel  ']
# -------------
# ['no  ']
# -------------
# ['dejar  ']
# -------------
# ['el  ']
# -------------
# ['poder  ']
# -------------
# ['mal  ']
# -------------
# ['mucho  ']
# -------------
# ['el  ']
# -------------
# ['el  ']
# -------------
# ['apestar  ']
# -------------
# ['por  ']
# -------------
# ['malo  ']
# -------------
# ['no  ']
# -------------
# ['puaj  ']
# -------------
# ['sonoro  ']
# -------------
# ['terrible  ']
# -------------
# ['el  ']
# -------------
# ['todo  ']
# -------------
# ['vacaciones  ']
# -------------
# ['genial  ']
# -------------
# ['robooo  ']
# -------------
# ['compartir  ']
# -------------
# ['muy  ']
# -------------
# ['pesimo  ']
# -------------
# ['grosero ,  ']
# -------------
# ['muy  ']
# -------------
# ['uno  ']
# -------------
# ['no  ']
# -------------
# ['']
# -------------
# ['$ $ $ terribles  ']
# -------------
# ['no  ']
# -------------
# ['el  ']
# -------------
# ['enfermo  ']
# -------------
# ['peligro ,  ']
# -------------
# ['muy  ']
# -------------
# ['lujoso ,  ']
# -------------
# ['mal  ']
# -------------
# ['no  ']
# -------------
# ['no  ']
# -------------
# ['el  ']
# -------------
# ['todavía  ']
# -------------
# ['desayuno  ']
# -------------
# ['malo  ']
# -------------
# ['malo  ']
# -------------
# ['peor  ']
# -------------
# ['uno  ']
# -------------
# ['nunca  ']
# -------------
# ['malo  ']
# -------------
# ['el  ']
# -------------
# ['cena  ']
# -------------
# ['malo  ']
# -------------
# ['mal  ']
# -------------
# ['ruido  ']
# -------------
# ['pesimo  ']
# -------------
# ['malo  ']
# -------------
# ['peor  ']
# -------------
# ['desagradable  ']
# -------------
# ['tanto  ']
# -------------
# ['no  ']
# -------------
# ['el  ']
# -------------
# ['sobrevalorar  ']
# -------------
# ['malo  ']
# -------------
# ['el  ']
# -------------
# ['asco  ']
# -------------
# ['el  ']
# -------------
# ['uno  ']
# -------------
# ['mal  ']
# -------------
# ['malo  ']
# -------------
# ['necesitar  ']
# -------------
# ['no  ']
# -------------
# ['haber  ']
# -------------
# ['tiempo  ']
# -------------
# ['excesivo  ']
# -------------
# ['ir  ']
# -------------
# ['presentación  ']
# -------------
# ['nunca  ']
# -------------
# ['bueno  ']
# -------------
# ['malo  ']
# -------------
# ['dejo  ']
# -------------
# ['piaf  ']
# -------------
# ['evitar  ']
# -------------
# ['blah !  ']
# -------------
# ['grande  ']
# -------------
# ['muy  ']
# -------------
# ['malo  ']
# -------------
# ['si  ']
# -------------
# ['inmensamente  ']
# -------------
# ['decepción  ']
# -------------
# ['discriminación  ']
# -------------
# ['ojo ! ! !  ']
# -------------
# ['decepcionar  ']
# -------------
# ['malo  ']
# -------------
# ['']
# -------------
# ['ten_además  ']
# -------------
# ['robar  ']
# -------------
# ['malo  ']
# -------------
# ['malo  ']
# -------------
# ['lamentablemente  ']
# -------------
# ['malo  ']
# -------------
# ['mediocridad  ']
# -------------
# ['actitud  ']
# -------------
# ['el  ']
# -------------
# ['escaso  ']
# -------------
# ['']
# -------------
# ['ten_decepcionante  ']
# -------------
# ['muy  ']
# -------------
# ['uno  ']
# -------------
# ['pesimo  ']
# -------------
# ['malo  ']
# -------------
# ['servicio  ']
# -------------
# ['abuso  ']
# -------------
# ['el  ']
# -------------
# ['trampa  ']
# -------------
# ['terrible  ']
# -------------
# ['uno  ']
# -------------
# ['no  ']
# -------------
# ['comprobar  ']
# -------------
# ['uno  ']
# -------------
# ['uno  ']
# -------------
# ['malo  ']
# -------------
# ['malo  ']
# -------------
# ['desayuno  ']
# -------------
# ['caro !  ']
# -------------
# ['malo  ']
# -------------
# ['malo  ']
# -------------
# ['ser  ']
# -------------
# ['pesima  ']
# -------------
# ['uno  ']
# -------------
# ['estancia  ']
# -------------
# ['¡ qué  ']
# -------------
# ['no  ']
# -------------
# ['no  ']
# -------------
# ['el  ']
# -------------
# ['evitar  ']
# -------------
# ['mal . ']
# -------------
# ['hotel  ']
# -------------
# ['¡ momia ,  ']
# -------------
# ['comida  ']
# -------------
# ['no  ']
# -------------
# ['momificar  ']
# -------------
# ['incómodo  ']
# -------------
# ['muy  ']
# -------------
# ['horrible  ']
# -------------
# ['odioso  ']
# -------------
# ['no  ']
# -------------
# ['esperar  ']
# -------------
# ['no  ']
# -------------
# ['ir  ']
# -------------
# ['gran  ']
# -------------
# ['no  ']
# -------------
# ['malo  ']
# -------------
# ['muy  ']
# -------------
# ['lugar  ']
# -------------
# ['no  ']
# -------------
# ['buff  ']
# -------------
# ['malo  ']
# -------------
# ['0  ']
# -------------
# ['deber  ']
# -------------
# ['tomar  ']
# -------------
# ['nada  ']
# -------------
# ['pequeño  ']
# -------------
# ['mal  ']
# -------------
# ['puro  ']
# -------------
# ['nada  ']
# -------------
# ['uno  ']
# -------------
# ['tener  ']
# -------------
# ['¡ que  ']
# -------------
# ['horrible  ']
# -------------
# ['uno  ']
# -------------
# ['momia  ']
# -------------
# ['horrible  ']
# -------------
# ['¡ uno  ']
# -------------
# ['¡ tétrico !  ']
# -------------
# ['nada  ']
# -------------
# ['de  ']
# -------------
# ['¡ malo !  ']
# -------------
# ['ocupar  ']
# -------------
# ['no  ']
# -------------
# ['es  ']
# -------------
# ['uno  ']
# -------------
# ['horrible  ']
# -------------
# ['decepcionante  ']
# -------------
# ['oler  ']
# -------------
# ['no  ']
# -------------
# ['morbo  ']
# -------------
# ['me  ']
# -------------
# ['totalmente  ']
# -------------
# ['aburrídisimo  ']
# -------------
# ['no  ']
# -------------
# ['sufrir  ']
# -------------
# ["don't  "]
# -------------
# ['muy  ']
# -------------
# ['no  ']
# -------------
# ['abandonar  ']
# -------------
# ['emblemático  ']
# -------------
# ['sucio  ']
# -------------
# ['decepción  ']
# -------------
# ['decepcionante  ']
# -------------
# ['¡ atascado !  ']
# -------------
# ['el  ']
# -------------
# ['uno  ']
# -------------
# ['no  ']
# -------------
# ['pequeño ,  ']
# -------------
# ['olor  ']
# -------------
# ['excelente  ']
# -------------
# ['descuidado  ']
# -------------
# ['¡ malo !  ']
# -------------
# ['callejón  ']
# -------------
# ['uno  ']
# -------------
# ['no  ']
# -------------
# ['horrible  ']
# -------------
# ['ser  ']
# -------------
# ['de  ']
# -------------
# ['no  ']
# -------------
# ['cual  ']
# -------------
# ['visita  ']
# -------------
# ['grand  ']
# -------------
# ['ese  ']
# -------------
# ['defraudar  ']
# -------------
# ['maravilloso  ']
# -------------
# ['normalmente  ']
# -------------
# ['ni  ']
# -------------
# ['principalmente  ']
# -------------
# ['servicio  ']
# -------------
# ['mal  ']
# -------------
# ['normal-mediocre  ']
# -------------
# ['grand  ']
# -------------
# ['no  ']
# -------------
# ['no  ']
# -------------
# ['muy  ']
# -------------
# ['pesima  ']
# -------------
# ['rebasar  ']
# -------------
# ['medio  ']
# -------------
# ['1  ']
# -------------
# ['¿ cómo  ']
# -------------
# ['demasiado  ']
# -------------
# ['robo  ']
# -------------
# ['haber  ']
# -------------
# ['pesimo  ']
# -------------
# ['decepcionar  ']
# -------------
# ['no  ']
# -------------
# ['mal  ']
# -------------
# ['quedar  ']
# -------------
# ['el  ']
# -------------
# ['construcción  ']
# -------------
# ['muy  ']
# -------------
# ['problema  ']
# -------------
# ['sobrevalorar  ']
# -------------
# ['no  ']
# -------------
# ['cada  ']
# -------------
# ['no  ']
# -------------
# ['decepcionante  ']
# -------------
# ['horrible  ']
# -------------
# ['lista  ']
# -------------
# ['obtener  ']
# -------------
# ['uno  ']
# -------------
# ['oler  ']
# -------------
# ['moho  ']
# -------------
# ['el  ']
# -------------
# ['nunca  ']
# -------------
# ['malo  ']
# -------------
# ['no  ']
# -------------
# ['entorno  ']
# -------------
# ['si  ']
# -------------
# ['hermoso  ']
# -------------
# ['estar  ']
# -------------
# ['no  ']
# -------------
# ['atrapar  ']
# -------------
# ['muy  ']
# -------------
# ['caro ,  ']
# -------------
# ['no  ']
# -------------
# ['solo  ']
# -------------
# ['estafa . ']
# -------------
# ['mal  ']
# -------------
# ['atrapar  ']
# -------------
# ['éxito  ']
# -------------
# ['hotel  ']
# -------------
# ['decepción  ']
# -------------
# ['no  ']
# -------------
# ['muy  ']
# -------------
# ['ni  ']
# -------------
# ['propietario  ']
# -------------
# ['muy ,  ']
# -------------
# ['este  ']
# -------------
# ['no  ']
# -------------
# ['pro  ']
# -------------
# ['para  ']
# -------------
# ['villa  ']
# -------------
# ['friamente  ']
# -------------
# ['ser  ']
# -------------
# ['alguno  ']
# -------------
# ['bueno  ']
# -------------
# ['mejora  ']
# -------------
# ['muy  ']
# -------------
# ['en  ']
# -------------
# ['desilucionado  ']
# -------------
# ['comida  ']
# -------------
# ['italiano ?  ']
# -------------
# ['mucho  ']
# -------------
# ['servicio  ']
# -------------
# ['platillo  ']
# -------------
# ['mal  ']
# -------------
# ['caro ,  ']
# -------------
# ['probar  ']
# -------------
# ['ok  ']
# -------------
# ['sobrevaluar  ']
# -------------
# ['ir  ']
# -------------
# ['bernice ,  ']
# -------------
# ['decepcionar  ']
# -------------
# ['1  ']
# -------------
# ['desayuno  ']
# -------------
# ['no  ']
# -------------
# ['no  ']
# -------------
# ['lástima  ']
# -------------
# ['2  ']
# -------------
# ['tomar  ']
# -------------
# ['¿ cuál  ']
# -------------
# ['uno  ']
# -------------
# ['ser  ']
# -------------
# ['no  ']
# -------------
# ['muy  ']
# -------------
# ['mal  ']
# -------------
# ['de  ']
# -------------
# ['hoy  ']
# -------------
# ['2  ']
# -------------
# ['no  ']
# -------------
# ['decepcionante  ']
# -------------
# ['decepcionante  ']
# -------------
# ['el  ']
# -------------
# ['menos  ']
# -------------
# ['todo  ']
# -------------
# ['ser  ']
# -------------
# ['no  ']
# -------------
# ['uno  ']
# -------------
# ['malo  ']
# -------------
# ['trampa  ']
# -------------
# ['sucio  ']
# -------------
# ['tan  ']
# -------------
# ['uno  ']
# -------------
# ['porción  ']
# -------------
# ['personal  ']
# -------------
# ['muy  ']
# -------------
# ['hotel  ']
# -------------
# ['esperar  ']
# -------------
# ['no  ']
# -------------
# ['decepcionar  ']
# -------------
# ['falta  ']
# -------------
# ['por  ']
# -------------
# ['no  ']
# -------------
# ['antes  ']
# -------------
# ['mal  ']
# -------------
# ['']
# -------------
# ['ten_mala  ']
# -------------
# ['mas  ']
# -------------
# ['bonito  ']
# -------------
# ['no  ']
# -------------
# ['mando  ']
# -------------
# ['gran  ']
# -------------
# ['not  ']
# -------------
# ['hacer  ']
# -------------
# ['el  ']
# -------------
# ['sobrevalorar  ']
# -------------
# ['hard  ']
# -------------
# ['no  ']
# -------------
# ['no  ']
# -------------
# ['ya  ']
# -------------
# ['no  ']
# -------------
# ['peor  ']
# -------------
# ['nunca  ']
# -------------
# ['malo  ']
# -------------
# ['no  ']
# -------------
# ['no  ']
# -------------
# ['no  ']
# -------------
# ['bullicio  ']
# -------------
# ['bueno  ']
# -------------
# ['muy  ']
# -------------
# ['el  ']
# -------------
# ['muy  ']
# -------------
# ['ingrediente  ']
# -------------
# ['estúpido  ']
# -------------
# ['cobrar  ']
# -------------
# ['decepcionar  ']
# -------------
# ['no  ']
# -------------
# ['breve  ']
# -------------
# ['torre  ']
# -------------
# ['']
# -------------
# ['ten_después  ']
# -------------
# ['ejecución  ']
# -------------
# ['simplemente  ']
# -------------
# ['bar  ']
# -------------
# ['el  ']
# -------------
# ['gente  ']
# -------------
# ['precio  ']
# -------------
# ['mantener  ']
# -------------
# ['habitación  ']
# -------------
# ['dudoso  ']
# -------------
# ['hermoso  ']
# -------------
# ['triste  ']
# -------------
# ['ruidoso ,  ']
# -------------
# ['ser  ']
# -------------
# ['2  ']
# -------------
# ['decepcionar  ']
# -------------
# ['absolutamente  ']
# -------------
# ['mucho  ']
# -------------
# ['bueno  ']
# -------------
# ['moda  ']
# -------------
# ['no  ']
# -------------
# ['pobre  ']
# -------------
# ['sólo  ']
# -------------
# ['personal  ']
# -------------
# ['genial  ']
# -------------
# ['estado  ']
# -------------
# ['no  ']
# -------------
# ['poder  ']
# -------------
# ['precioso  ']
# -------------
# ['no  ']
# -------------
# ['agradable  ']
# -------------
# ['el  ']
# -------------
# ['clasificación  ']
# -------------
# ['uno  ']
# -------------
# ['no  ']
# -------------
# ['viejo ,  ']
# -------------
# ['no  ']
# -------------
# ['este  ']
# -------------
# ['no  ']
# -------------
# ['enormemente  ']
# -------------
# ['muy  ']
# -------------
# ['continuar  ']
# -------------
# ['sucio  ']
# -------------
# ['instalación  ']
# -------------
# ['regular  ']
# -------------
# ['decepcionante . ']
# -------------
# ['malo  ']
# -------------
# ['decepcionante . ']
# -------------
# ['demasiado  ']
# -------------
# ['renovar  ']
# -------------
# ['muy  ']
# -------------
# ['más  ']
# -------------
# ['vacaciones  ']
# -------------
# ['mediocre  ']
# -------------
# ['terrible  ']
# -------------
# ['genial  ']
# -------------
# ['mal  ']
# -------------
# ['seguridad  ']
# -------------
# ['bonito ,  ']
# -------------
# ['mentalidad  ']
# -------------
# ['servicio  ']
# -------------
# ['mas  ']
# -------------
# ['pesimo  ']
# -------------
# ['nuestro  ']
# -------------
# ['caro  ']
# -------------
# ['nada  ']
# -------------
# ['experiencia  ']
# -------------
# ['el  ']
# -------------
# ['vacaciones  ']
# -------------
# ['parte  ']
# -------------
# ['prisión  ']
# -------------
# ['servicio  ']
# -------------
# ['aviso  ']
# -------------
# ['hard  ']
# -------------
# ['el  ']
# -------------
# ['el  ']
# -------------
# ['mal  ']
# -------------
# ['uno  ']
# -------------
# ['servicio  ']
# -------------
# ['buffet  ']
# -------------
# ['el  ']
# -------------
# ['uno  ']
# -------------
# ['comida  ']
# -------------
# ['no  ']
# -------------
# ['el  ']
# -------------
# ['si  ']
# -------------
# ['irregular  ']
# -------------
# ['malo  ']
# -------------
# ['el  ']
# -------------
# ['no  ']
# -------------
# ['precio  ']
# -------------
# ['de  ']
# -------------
# ['no  ']
# -------------
# ['para  ']
# -------------
# ['2  ']
# -------------
# ['no  ']
# -------------
# ['ser  ']
# -------------
# ['el  ']
# -------------
# ['no  ']
# -------------
# ['no  ']
# -------------
# ['no  ']
# -------------
# ['fiesta  ']
# -------------
# ['no  ']
# -------------
# ['comida  ']
# -------------
# ['']
# -------------
# ['$14 proceso  ']
# -------------
# ['imitación  ']
# -------------
# ['|  ']
# -------------
# ['bueno  ']
# -------------
# ['nunca  ']
# -------------
# ['no  ']
# -------------
# ['demasiado  ']
# -------------
# ['flan  ']
# -------------
# ['no  ']
# -------------
# ['mano  ']
# -------------
# ['bueno  ']
# -------------
# ['nunca  ']
# -------------
# ['no  ']
# -------------
# ['el  ']
# -------------
# ['muy  ']
# -------------
# ['noche  ']
# -------------
# ['ser  ']
# -------------
# ['si  ']
# -------------
# ['el  ']
# -------------
# ['el  ']
# -------------
# ['preferencia  ']
# -------------
# ['celebración  ']
# -------------
# ['no  ']
# -------------
# ['no  ']
# -------------
# ['disappoiontment  ']
# -------------
# ['hotel  ']
# -------------
# ['no  ']
# -------------
# ['parada !  ']
# -------------
# ['malo  ']
# -------------
# ['muy  ']
# -------------
# ['no  ']
# -------------
# ['gran  ']
# -------------
# ['decepcionar  ']
# -------------
# ['aislar  ']
# -------------
# ['soler  ']
# -------------
# ['no  ']
# -------------
# ['el  ']
# -------------
# ['¿ qué  ']
# -------------
# ['mantener  ']
# -------------
# ['gran  ']
# -------------
# ['']
# -------------
# ['ten_leeeento  ']
# -------------
# ['lento  ']
# -------------
# ['me  ']
# -------------
# ['ojalá  ']
# -------------
# ['todo  ']
# -------------
# ['muy  ']
# -------------
# ['no  ']
# -------------
# ['uno  ']
# -------------
# ['perdon  ']
# -------------
# ['']
# -------------
# ['x uno  ']
# -------------
# ['queja  ']
# -------------
# ['el  ']
# -------------
# ['ubicación  ']
# -------------
# ['decepcionante  ']
# -------------
# ['exceso  ']
# -------------
# ['intoxicación  ']
# -------------
# ['el  ']
# -------------
# ['mal  ']
# -------------
# ['que  ']
# -------------
# ['el  ']
# -------------
# ['elvis  ']
# -------------
# ['haber  ']
# -------------
# ['no  ']
# -------------
# ['no  ']
# -------------
# ['ser  ']
# -------------
# ['hot  ']
# -------------
# ['no  ']
# -------------
# ['decepción  ']
# -------------
# ['2-1  ']
# -------------
# ['que  ']
# -------------
# ['parecer  ']
# -------------
# ['no  ']
# -------------
# ['uno  ']
# -------------
# ['uno  ']
# -------------
# ['medio  ']
# -------------
# ['grand  ']
# -------------
# ['villa  ']
# -------------
# ['pesima  ']
# -------------
# ['evitar  ']
# -------------
# ['no  ']
# -------------
# ['estar  ']
# -------------
# ['no  ']
# -------------
# ['bajo  ']
# -------------
# ['estar  ']
# -------------
# ['comida  ']
# -------------
# ['decepcionar  ']
# -------------
# ['malo  ']
# -------------
# ['sobrevalorar  ']
# -------------
# ['el  ']
# -------------
# ['ir  ']
# -------------
# ['esperar  ']
# -------------
# ['mal  ']
# -------------
# ['terrible  ']
# -------------
# ['5  ']
# -------------
# ['no  ']
# -------------
# ['muy  ']
# -------------
# ['ya  ']
# -------------
# ['']
# -------------
# ['ten_mal  ']
# -------------
# ['menos  ']
# -------------
# ['comida  ']
# -------------
# ['grand  ']
# -------------
# ['muy  ']
# -------------
# ['no  ']
# -------------
# ['no  ']
# -------------
# ['mal  ']
# -------------
# ['muy  ']
# -------------
# ['decepcionante  ']
# -------------
# ['desayuno  ']
# -------------
# ['']
# -------------
# ['a_se  ']
# -------------
# ['desaparecer  ']
# -------------
# ['el  ']
# -------------
# ['hotel  ']
# -------------
# ['intervalo  ']
# -------------
# ['mal  ']
# -------------
# ['ambiente  ']
# -------------
# ['el  ']
# -------------
# ['caro ,  ']
# -------------
# ['cara  ']
# -------------
# ['mucho  ']
# -------------
# ['pizza  ']
# -------------
# ['ya  ']
# -------------
# ['bueno  ']
# -------------
# ['malo  ']
# -------------
# ['uno  ']
# -------------
# ['vacaciones  ']
# -------------
# ['no  ']
# -------------
# ['muy  ']
# -------------
# ['sobrevalorar  ']
# -------------
# ['aceptable  ']
# -------------
# ['horrible  ']
# -------------
# ['servicio  ']
# -------------
# ['decepcionar  ']
# -------------
# ['decepcionar  ']
# -------------
# ['no  ']
# -------------
# ['mal  ']
# -------------
# ['evitar  ']
# -------------
# ['experiencia  ']
# -------------
# ['esperar  ']
# -------------
# ['no  ']
# -------------
# ['mediocre  ']
# -------------
# ['en  ']
# -------------
# ['pudrir  ']
# -------------
# ['decepcionante . ']
# -------------
# ['como  ']
# -------------
# ['que  ']
# -------------
# ['muy  ']
# -------------
# ['comida  ']
# -------------
# ['']
# -------------
# ['$14 mucho  ']
# -------------
# ['bien  ']
# -------------
# ['caro  ']
# -------------
# ['probablemente  ']
# -------------
# ['hermoso  ']
# -------------
# ['cena  ']
# -------------
# ['bien  ']
# -------------
# ['muy  ']
# -------------
# ['decepcionante . ']
# -------------
# ['decepción  ']
# -------------
# ['bueno ,  ']
# -------------
# ['descriminar  ']
# -------------
# ['demasiado  ']
# -------------
# ['ojo  ']
# -------------
# ['nos  ']
# -------------
# ['sugerencia  ']
# -------------
# ['muy  ']
# -------------
# ['agradable  ']
# -------------
# ['comida  ']
# -------------
# ['alojar  ']
# -------------
# ['el  ']
# -------------
# ['lastimar  ']
# -------------
# ['no  ']
# -------------
# ['no  ']
# -------------
# ['república  ']
# -------------
# ['. ']
# -------------
# ['dinnee  ']
# -------------
# ['normal  ']
# -------------
# ['preparar  ']
# -------------
# ['no  ']
# -------------
# ['no  ']
# -------------
# ['el  ']
# -------------
# ['2-1  ']
# -------------
# ['todo  ']
# -------------
# ['destino  ']
# -------------
# ['no  ']
# -------------
# ['cada  ']
# -------------
# ['insatisfecho  ']
# -------------
# ['bueno  ']
# -------------
# ['no  ']
# -------------
# ['natación  ']
# -------------
# ['disappoiontment  ']
# -------------
# ['multipropiedad  ']
# -------------
# ['dejar  ']
# -------------
# ['nunca  ']
# -------------
# ['comida  ']
# -------------
# ['no  ']
# -------------
# ['bueno  ']
# -------------
# ['sobrevalorar  ']
# -------------
# ['deber  ']
# -------------
# ['ser  ']
# -------------
# ['ser  ']
# -------------
# ['el  ']
# -------------
# ['nocturno  ']
# -------------
# ['no  ']
# -------------
# ['ni  ']
# -------------
# ['no  ']
# -------------
# ['fiesta  ']
# -------------
# ['camarón  ']
# -------------
# ['no  ']
# -------------
# ['para  ']
# -------------
# ['plato  ']
# -------------
# ['¿ que  ']
# -------------
# ['malo  ']
# -------------
# ['muy  ']
# -------------
# ['decir  ']
# -------------
# ['el  ']
# -------------
# ['no  ']
# -------------
# ['el  ']
# -------------
# ['mal  ']
# -------------
# ['cucaracha  ']
# -------------
# ['el  ']
# -------------
# ['bueno  ']
# -------------
# ['no  ']
# -------------
# ['el  ']
# -------------
# ['ir  ']
# -------------
# ['dudoso  ']
# -------------
# ['mal  ']
# -------------
# ['»  ']
# -------------
# ['le  ']
# -------------
# ['muy  ']
# -------------
# ['no  ']
# -------------
# ['2  ']
# -------------
# ['malo  ']
# -------------
# ['el  ']
# -------------
# ['más  ']
# -------------
# ['habitación  ']
# -------------
# ['decepcionar  ']
# -------------
# ['no  ']
# -------------
# ['cada  ']
# -------------
# ['este  ']
# -------------
# ['ubicación  ']
# -------------
# ['tener  ']
# -------------
# ['¿ qué  ']
# -------------
# ['']
# -------------
# ['$ $ $ no  ']
# -------------
# ['no  ']
# -------------
# ['mal  ']
# -------------
# ['mucho  ']
# -------------
# ['muy  ']
# -------------
# ['decepcionante  ']
# -------------
# ['bueno  ']
# -------------
# ['ughhhh !  ']
# -------------
# ['horrible !  ']
# -------------
# ['presuntuoso  ']
# -------------
# ['bullicio  ']
# -------------
# ['no  ']
# -------------
# ['propiedad  ']
# -------------
# ['no  ']
# -------------
# ['uno  ']
# -------------
# ['se  ']
# -------------
# ['rollo  ']
# -------------
# ['hotel  ']
# -------------
# ['plan  ']
# -------------
# ['gran  ']
# -------------
# ['quizás  ']
# -------------
# ['malo  ']
# -------------
# ['precio  ']
# -------------
# ['decepcionante  ']
# -------------
# ['muy  ']
# -------------
# ['racista  ']
# -------------
# ['decepcionar  ']
# -------------
# ['correr  ']
# -------------
# ['no  ']
# -------------
# ['mal  ']
# -------------
# ['el  ']
# -------------
# ['este  ']
# -------------
# ['gran  ']
# -------------
# ['popular ,  ']
# -------------
# ['1  ']
# -------------
# ['no  ']
# -------------
# ['todo  ']
# -------------
# ['mejor  ']
# -------------
# ['mal  ']
# -------------
# ['pesima  ']
# -------------
# ['mal  ']
# -------------
# ['cómo  ']
# -------------
# ['instalación  ']
# -------------
# ['']
# -------------
# ['a_uf  ']
# -------------
# ['me  ']
# -------------
# ['decepcionar  ']
# -------------
# ['comida  ']
# -------------
# ['desayuno  ']
# -------------
# ['ir  ']
# -------------
# ['expectativa  ']
# -------------
# ['malo  ']
# -------------
# ['lugar  ']
# -------------
# ['el  ']
# -------------
# ['vacaciones  ']
# -------------
# ['lleno  ']
# -------------
# ['estafa  ']
# -------------
# ['muy  ']
# -------------
# ['malo  ']
# -------------
# ['el  ']
# -------------
# ['trattoria  ']
# -------------
# ['nunca  ']
# -------------
# ['el  ']
# -------------
# ['chorrada  ']
# -------------
# ['momia  ']
# -------------
# ['turismo  ']
# -------------
# ['no  ']
# -------------
# ['sólo  ']
# -------------
# ['muy  ']
# -------------
# ['muy  ']
# -------------
# ['15  ']
# -------------
# ['aburrir  ']
# -------------
# ['esperar  ']
# -------------
# ['historia  ']
# -------------
# ['sólo  ']
# -------------
# ['oler  ']
# -------------
# ['asustar  ']
# -------------
# ['el  ']
# -------------
# ['interasante  ']
# -------------
# ['el  ']
# -------------
# ['obligar  ']
# -------------
# ['con  ']
# -------------
# ['malo  ']
# -------------
# ['cerrar  ']
# -------------
# ['museo  ']
# -------------
# ['bueno  ']
# -------------
# ['']
# -------------
# ['sos_monumento  ']
# -------------
# ['uno  ']
# -------------
# ['pobre  ']
# -------------
# ['defraudar  ']
# -------------
# ['pena  ']
# -------------
# ['puro  ']
# -------------
# ['el  ']
# -------------
# ['no  ']
# -------------
# ['no  ']
# -------------
# ['mucho  ']
# -------------
# ['¡ no  ']
# -------------
# ['malo  ']
# -------------
# ['en  ']
# -------------
# ['nada  ']
# -------------
# ['museo  ']
# -------------
# ['prescindible  ']
# -------------
# ['por  ']
# -------------
# ['valer  ']
# -------------
# ['no  ']
# -------------
# ['sólo  ']
# -------------
# ['uno  ']
# -------------
# ['hermoso  ']
# -------------
# ['sin  ']
# -------------
# ['no  ']
# -------------
# ['caro  ']
# -------------
# ['¡ muy  ']
# -------------
# ['mucho  ']
# -------------
# ['decepcionante  ']
# -------------
# ['el  ']
# -------------
# ['visita  ']
# -------------
# ['no  ']
# -------------
# ['se  ']
# -------------
# ['sobrevalorar  ']
# -------------
# ['muy  ']
# -------------
# ['decepcionante  ']
# -------------
# ['no  ']
# -------------
# ['bored  ']
# -------------
# ['cerrar  ']
# -------------
# ['decepcionante  ']
# -------------
# ['opinión  ']
# -------------
# ['malo  ']
# -------------
# ['no  ']
# -------------
# ['parecer  ']
# -------------
# ['no  ']
# -------------
# ['sucio  ']
# -------------
# ['básico  ']
# -------------
# ['momia  ']
# -------------
# ['']
# -------------
# ['decepcionante  no  ']
# -------------
# ['uno  ']
# -------------
# ['regulación  ']
# -------------
# ['mejorable  ']
# -------------
# ['saturar  ']
# -------------
# ['asfixiante  ']
# -------------
# ['muy  ']
# -------------
# ['visita  ']
# -------------
# ['lugar  ']
# -------------
# ['ser  ']
# -------------
# ['se  ']
# -------------
# ['lugar  ']
# -------------
# ['uno  ']
# -------------
# ['pequeño  ']
# -------------
# ['mercado  ']
# -------------
# ['en  ']
# -------------
# ['paseo  ']
# -------------
# ['no  ']
# -------------
# ['regular  ']
# -------------
# ['mal  ']
# -------------
# ['bueno  ']
# -------------
# ['interesante  ']
# -------------
# ['no  ']
# -------------
# ['lugar  ']
# -------------
# ['decepcionante  ']
# -------------
# ['nada  ']
# -------------
# ['no  ']
# -------------
# ['mal  ']
# -------------
# ['15  ']
# -------------
# ['sin  ']
# -------------
# ['distinto  ']
# -------------
# ['no  ']
# -------------
# ['a el  ']
# -------------
# ['ser  ']
# -------------
# ['sin  ']
# -------------
# ['¡ ¡ ¡ ya  ']
# -------------
# ['¡ no  ']
# -------------
# ['demasiado  ']
# -------------
# ['sucio  ']
# -------------
# ['no  ']
# -------------
# ['largo  ']
# -------------
# ['uno  ']
# -------------
# ['museo  ']
# -------------
# ['cada  ']
# -------------
# ['guanajuato  ']
# -------------
# ['acosador  ']
# -------------
# ['decepción  ']
# -------------
# ['lleno  ']
# -------------
# ['costoso  ']
# -------------
# ['1  ']
# -------------
# ['no  ']
# -------------
# ['visita  ']
# -------------
# ['caro  ']
# -------------
# ['visita  ']
# -------------
# ['muy  ']
# -------------
# ['creer  ']
# -------------
# ['uno  ']
# -------------
# ['tener  ']
# -------------
# ['uno  ']
# -------------
# ['demasiado  ']
# -------------
# ['ver  ']
# -------------
# ['bonito  ']
# -------------
# ['macabrooo  ']
# -------------
# ['lugar  ']
# -------------
# ['turistada  ']
# -------------
# ['fuchi ,  ']
# -------------
# ['¡ mucho  ']
# -------------
# ['parada  ']
# -------------
# ['miedo  ']
# -------------
# ['temático  ']
# -------------
# ['esperar  ']
# -------------
# ['algo  ']
# -------------
# ['para  ']
# -------------
# ['huevo  ']
# -------------
# ['malo -  ']
# -------------
# ['decepcionante . ']
# -------------
# ['bonito  ']
# -------------
# ['inesperado  ']
# -------------
# ['bueno  ']
# -------------
# ['eddie  ']
# -------------
# ['impersonal  ']
# -------------
# ['cena  ']
# -------------
# ['last  ']
# -------------
# ['5  ']
# -------------
# ['no  ']
# -------------
# ['todo  ']
# -------------
# ['no  ']
# -------------
# ['el  ']
# -------------
# ['bueno  ']
# -------------
# ['servicio  ']
# -------------
# ['el  ']
# -------------
# ['bonito  ']
# -------------
# ['más  ']
# -------------
# ['gloria  ']
# -------------
# ['algo  ']
# -------------
# ['el  ']
# -------------
# ['el  ']
# -------------
# ['uno  ']
# -------------
# ['alto  ']
# -------------
# ['poder  ']
# -------------
# ['algo  ']
# -------------
# ['el  ']
# -------------
# ['bueno  ']
# -------------
# ['mayar  ']
# -------------
# ['experiencia  ']
# -------------
# ['no  ']
# -------------
# ['multipropiedad  ']
# -------------
# ['bueno  ']
# -------------
# ['bueno  ']
# -------------
# ['nuestro  ']
# -------------
# ['normal  ']
# -------------
# ['muy  ']
# -------------
# ['nada  ']
# -------------
# ['sabroso  ']
# -------------
# ['lugar  ']
# -------------
# ['esperar  ']
# -------------
# ['vino  ']
# -------------
# ['no  ']
# -------------
# ['magnífico  ']
# -------------
# ['demasiado  ']
# -------------
# ['no  ']
# -------------
# ['bueno ,  ']
# -------------
# ['prueba  ']
# -------------
# ['gran  ']
# -------------
# ['gran  ']
# -------------
# ['uno  ']
# -------------
# ['genial  ']
# -------------
# ['check  ']
# -------------
# ['vacaciones  ']
# -------------
# ['decepcionante  ']
# -------------
# ['uno  ']
# -------------
# ['mal  ']
# -------------
# ['ambiente  ']
# -------------
# ['food  ']
# -------------
# ['comida  ']
# -------------
# ['gran  ']
# -------------
# ['el  ']
# -------------
# ['el  ']
# -------------
# ['nuevo  ']
# -------------
# ['mejor  ']
# -------------
# ['belleza  ']
# -------------
# ['ya  ']
# -------------
# ['bajar  ']
# -------------
# ['si  ']
# -------------
# ['bueno  ']
# -------------
# ['rico  ']
# -------------
# ['este  ']
# -------------
# ['villa  ']
# -------------
# ['hermoso  ']
# -------------
# ['básico  ']
# -------------
# ['haber  ']
# -------------
# ['mas  ']
# -------------
# ['marisco  ']
# -------------
# ['necesario  ']
# -------------
# ['dejo  ']
# -------------
# ['poco  ']
# -------------
# ['te  ']
# -------------
# ['american  ']
# -------------
# ['sugerencia  ']
# -------------
# ['muy  ']
# -------------
# ['mal  ']
# -------------
# ['desayuno  ']
# -------------
# ['gong  ']
# -------------
# ['bueno  ']
# -------------
# ['me  ']
# -------------
# ['bueno  ']
# -------------
# ['el  ']
# -------------
# ['']
# -------------
# ['a_gran  ']
# -------------
# ['nada  ']
# -------------
# ['sin  ']
# -------------
# ['mediocre  ']
# -------------
# ['inconsistente  ']
# -------------
# ['malo  ']
# -------------
# ['marisco  ']
# -------------
# ['haber  ']
# -------------
# ['no  ']
# -------------
# ['grand  ']
# -------------
# ['bueno  ']
# -------------
# ['barato  ']
# -------------
# ['bueno  ']
# -------------
# ['limpio ,  ']
# -------------
# ['feria  ']
# -------------
# ['yo  ']
# -------------
# ['bueno ,  ']
# -------------
# ['']
# -------------
# ['r_esperaba  ']
# -------------
# ['si  ']
# -------------
# ['aceptable  ']
# -------------
# ['']
# -------------
# ['ten_gran  ']
# -------------
# ['apartamento  ']
# -------------
# ['bueno  ']
# -------------
# ['el  ']
# -------------
# ['lugar  ']
# -------------
# ['estupendo  ']
# -------------
# ['no  ']
# -------------
# ['13  ']
# -------------
# ['bueno  ']
# -------------
# ['lugar  ']
# -------------
# ['servicio  ']
# -------------
# ['engañoso  ']
# -------------
# ['el  ']
# -------------
# ['sabroso  ']
# -------------
# ['no  ']
# -------------
# ['ir  ']
# -------------
# ['estupendo  ']
# -------------
# ['comida  ']
# -------------
# ['uno  ']
# -------------
# ['chico  ']
# -------------
# ['zarandear  ']
# -------------
# ['ya  ']
# -------------
# ['falta  ']
# -------------
# ['el  ']
# -------------
# ['bueno  ']
# -------------
# ['2  ']
# -------------
# ['samba  ']
# -------------
# ['aspecto  ']
# -------------
# ['ser  ']
# -------------
# ['samba  ']
# -------------
# ['bueno ,  ']
# -------------
# ['bueno  ']
# -------------
# ['viaje  ']
# -------------
# ['vacaciones  ']
# -------------
# ['no  ']
# -------------
# ['me  ']
# -------------
# ['mal  ']
# -------------
# ['bueno ,  ']
# -------------
# ['carnicería  ']
# -------------
# ['el  ']
# -------------
# ['bonito  ']
# -------------
# ['poder  ']
# -------------
# ['no  ']
# -------------
# ['uno  ']
# -------------
# ['fantástico  ']
# -------------
# ['el  ']
# -------------
# ['de  ']
# -------------
# ['🤔  ']
# -------------
# ['excelente  ']
# -------------
# ['aburrir  ']
# -------------
# ['no  ']
# -------------
# ['vacaciones  ']
# -------------
# ['el  ']
# -------------
# ['no  ']
# -------------
# ['pizza  ']
# -------------
# ['bueno  ']
# -------------
# ['restaurante  ']
# -------------
# ['no  ']
# -------------
# ['hotel  ']
# -------------
# ['recomendable  ']
# -------------
# ['en  ']
# -------------
# ['regular  ']
# -------------
# ['bueno  ']
# -------------
# ['el  ']
# -------------
# ['dejar  ']
# -------------
# ['sabroso  ']
# -------------
# ['el  ']
# -------------
# ['el  ']
# -------------
# ['simplemente  ']
# -------------
# ['le  ']
# -------------
# ['muy  ']
# -------------
# ['demasiado  ']
# -------------
# ['bueno  ']
# -------------
# ['cumplir  ']
# -------------
# ['ser  ']
# -------------
# ['experiencia  ']
# -------------
# ['mal  ']
# -------------
# ['']
# -------------
# ['']
# -------------
# ['ten_a_la  ']
# -------------
# ['habitación  ']
# -------------
# ['no  ']
# -------------
# ['no  ']
# -------------
# ['mal  ']
# -------------
# ['por  ']
# -------------
# ['tener  ']
# -------------
# ['gran  ']
# -------------
# ['demasiado  ']
# -------------
# ['gente  ']
# -------------
# ['no  ']
# -------------
# ['no  ']
# -------------
# ['no  ']
# -------------
# ['bonito  ']
# -------------
# ['medio . ']
# -------------
# ['bien ,  ']
# -------------
# ['hotel  ']
# -------------
# ['agradable  ']
# -------------
# ['no  ']
# -------------
# ['bueno  ']
# -------------
# ['ir  ']
# -------------
# ['nos  ']
# -------------
# ['suficiente  ']
# -------------
# ['me  ']
# -------------
# ['']
# -------------
# ['a_agradable  ']
# -------------
# ['equis  ']
# -------------
# ['mezcla  ']
# -------------
# ['no  ']
# -------------
# ['rico ,  ']
# -------------
# ['pizza  ']
# -------------
# ['servicio  ']
# -------------
# ['marisco  ']
# -------------
# ['el  ']
# -------------
# ['pescado  ']
# -------------
# ['hermoso  ']
# -------------
# ['agradable  ']
# -------------
# ['seevicui  ']
# -------------
# ['pase  ']
# -------------
# ['servicio  ']
# -------------
# ['hotel  ']
# -------------
# ['bonito  ']
# -------------
# ['ser  ']
# -------------
# ['desafortunadamente  ']
# -------------
# ['eddies  ']
# -------------
# ['bueno ,  ']
# -------------
# ['excelente  ']
# -------------
# ['hermoso  ']
# -------------
# ['no  ']
# -------------
# ['bueno  ']
# -------------
# ['desilusión  ']
# -------------
# ['bueno  ']
# -------------
# ['nos  ']
# -------------
# ['normal !  ']
# -------------
# ['deber  ']
# -------------
# ['si ,  ']
# -------------
# ['bonito  ']
# -------------
# ['no  ']
# -------------
# ['uno  ']
# -------------
# ['gran  ']
# -------------
# ['pro  ']
# -------------
# ['gran  ']
# -------------
# ['correcto ,  ']
# -------------
# ['pequeño  ']
# -------------
# ['ir  ']
# -------------
# ['no  ']
# -------------
# ['ambiente  ']
# -------------
# ['alimento  ']
# -------------
# ['cena  ']
# -------------
# ['desayuno  ']
# -------------
# ['cena  ']
# -------------
# ['moonstar  ']
# -------------
# ['peor  ']
# -------------
# ['falta  ']
# -------------
# ['esperar  ']
# -------------
# ['bueno  ']
# -------------
# ['valor  ']
# -------------
# ['bueno  ']
# -------------
# ['ser  ']
# -------------
# ['bueno  ']
# -------------
# ['bueno  ']
# -------------
# ['señor  ']
# -------------
# ['malo  ']
# -------------
# ['bueno  ']
# -------------
# ['creer  ']
# -------------
# ['comida  ']
# -------------
# ['precioso  ']
# -------------
# ['nos  ']
# -------------
# ['calification  ']
# -------------
# ['hotel  ']
# -------------
# ['mucho  ']
# -------------
# ['utilizar  ']
# -------------
# ['prestar  ']
# -------------
# ['simplemente  ']
# -------------
# ['no  ']
# -------------
# ['el  ']
# -------------
# ['bonito  ']
# -------------
# ['ambiente  ']
# -------------
# ['no  ']
# -------------
# ['no  ']
# -------------
# ['lugar  ']
# -------------
# ['ser  ']
# -------------
# ['']
# -------------
# ['x_poco  ']
# -------------
# ['okay  ']
# -------------
# ['haber  ']
# -------------
# ['bien  ']
# -------------
# ['demasiado  ']
# -------------
# ['opción  ']
# -------------
# ['bien ,  ']
# -------------
# ['bueno ,  ']
# -------------
# ['el  ']
# -------------
# ['el  ']
# -------------
# ['2  ']
# -------------
# ['comida  ']
# -------------
# ['sentimiento  ']
# -------------
# ['a  ']
# -------------
# ['lento  ']
# -------------
# ['vallarta  ']
# -------------
# ['no  ']
# -------------
# ['mucho  ']
# -------------
# ['no  ']
# -------------
# ['no  ']
# -------------
# ['poder  ']
# -------------
# ['algo  ']
# -------------
# ['mucho  ']
# -------------
# ['muy  ']
# -------------
# ['cena  ']
# -------------
# ['hotel  ']
# -------------
# ['']
# -------------
# ['tardadisimo  zzzzz  regular  ']
# -------------
# ['samba  ']
# -------------
# ['bueno  ']
# -------------
# ['no  ']
# -------------
# ['el  ']
# -------------
# ['uno  ']
# -------------
# ['hotel  ']
# -------------
# ['el  ']
# -------------
# ['hermoso  ']
# -------------
# ['bueno  ']
# -------------
# ['huesped  ']
# -------------
# ['muy  ']
# -------------
# ['el  ']
# -------------
# ['ser  ']
# -------------
# ['no  ']
# -------------
# ['bueno  ']
# -------------
# ['mismo  ']
# -------------
# ['no  ']
# -------------
# ['pobre  ']
# -------------
# ['complejo  ']
# -------------
# ['demasiado  ']
# -------------
# ['ya  ']
# -------------
# ['no  ']
# -------------
# ['calidad  ']
# -------------
# ['ser  ']
# -------------
# ['lugar  ']
# -------------
# ['el  ']
# -------------
# ['obtener  ']
# -------------
# ['nuestro  ']
# -------------
# ['haber  ']
# -------------
# ['no  ']
# -------------
# ['decepcionar  ']
# -------------
# ['simplemente  ']
# -------------
# ['bueno  ']
# -------------
# ['caro  ']
# -------------
# ['no  ']
# -------------
# ['correcto  ']
# -------------
# ['22  ']
# -------------
# ['comida  ']
# -------------
# ['necesario  ']
# -------------
# ['bueno ,  ']
# -------------
# ['tan  ']
# -------------
# ['pobre  ']
# -------------
# ['visita  ']
# -------------
# ['lujo  ']
# -------------
# ['el  ']
# -------------
# ['me  ']
# -------------
# ['bueno  ']
# -------------
# ['uno  ']
# -------------
# ['bueno  ']
# -------------
# ['línea  ']
# -------------
# ['bueno  ']
# -------------
# ['pequeño  ']
# -------------
# ['no  ']
# -------------
# ['agradable  ']
# -------------
# ['comida  ']
# -------------
# ['el  ']
# -------------
# ['esperar  ']
# -------------
# ['bueno  ']
# -------------
# ['sugerencia  ']
# -------------
# ['mejor  ']
# -------------
# ['desconforme  ']
# -------------
# ['construcción  ']
# -------------
# ['el  ']
# -------------
# ['2013  ']
# -------------
# ['uno  ']
# -------------
# ['uno  ']
# -------------
# ['el  ']
# -------------
# ['bueno ,  ']
# -------------
# ['nv  ']
# -------------
# ['1  ']
# -------------
# ['ser  ']
# -------------
# ['sencillo ,  ']
# -------------
# ['volver  ']
# -------------
# ['el  ']
# -------------
# ['sobrevalorar  ']
# -------------
# ['bueno  ']
# -------------
# ['megaresort  ']
# -------------
# ['lugar  ']
# -------------
# ['desayuno  ']
# -------------
# ['bueno  ']
# -------------
# ['muy  ']
# -------------
# ['no  ']
# -------------
# ['uno  ']
# -------------
# ['medio  ']
# -------------
# ['tardar  ']
# -------------
# ['lucca  ']
# -------------
# ['bueno  ']
# -------------
# ['hard  ']
# -------------
# ['desayuno  ']
# -------------
# ['necesidad  ']
# -------------
# ['molestia  ']
# -------------
# ['no  ']
# -------------
# ['precioso ,  ']
# -------------
# ['sitio  ']
# -------------
# ['encantador  ']
# -------------
# ['personal  ']
# -------------
# ['presentacion  ']
# -------------
# ['stick  ']
# -------------
# ['no  ']
# -------------
# ['escapada  ']
# -------------
# ['pesimo  ']
# -------------
# ['estupendo  ']
# -------------
# ['no  ']
# -------------
# ['bueno  ']
# -------------
# ['confuso  ']
# -------------
# ['bueno  ']
# -------------
# ['sabroso  ']
# -------------
# ['no  ']
# -------------
# ['el  ']
# -------------
# ['cumplir  ']
# -------------
# ['hermoso  ']
# -------------
# ['malo  ']
# -------------
# ['descanso  ']
# -------------
# ['nada  ']
# -------------
# ['preparar  ']
# -------------
# ['promedio  ']
# -------------
# ['el  ']
# -------------
# ['bueno  ']
# -------------
# ['paraíso ,  ']
# -------------
# ['estar  ']
# -------------
# ['bueno  ']
# -------------
# ['malo  ']
# -------------
# ['servicio  ']
# -------------
# ['cinismo  ']
# -------------
# ['bonito  ']
# -------------
# ['sin  ']
# -------------
# ['mucho  ']
# -------------
# ['costar  ']
# -------------
# ['el  ']
# -------------
# ['chico  ']
# -------------
# ['habitación  ']
# -------------
# ['gran  ']
# -------------
# ['rapido ,  ']
# -------------
# ['el  ']
# -------------
# ['vacaciones  ']
# -------------
# ['samba  ']
# -------------
# ['elegante  ']
# -------------
# ['el  ']
# -------------
# ['no  ']
# -------------
# ['siempre  ']
# -------------
# ['bonito  ']
# -------------
# ['no  ']
# -------------
# ['muy  ']
# -------------
# ['coma  ']
# -------------
# ['opinión  ']
# -------------
# ['bueno  ']
# -------------
# ['precioso ,  ']
# -------------
# ['quedar  ']
# -------------
# ['ubicación  ']
# -------------
# ['el  ']
# -------------
# ['nos  ']
# -------------
# ['bastante  ']
# -------------
# ['bien ,  ']
# -------------
# ['no  ']
# -------------
# ['bueno  ']
# -------------
# ['poder  ']
# -------------
# ['desayuno  ']
# -------------
# ['todo  ']
# -------------
# ['normal  ']
# -------------
# ['le  ']
# -------------
# ['impredecible  ']
# -------------
# ['este  ']
# -------------
# ['feria  ']
# -------------
# ['']
# -------------
# ['ten parada  ']
# -------------
# ['regular  ']
# -------------
# ['bueno  ']
# -------------
# ['bueno  ']
# -------------
# ['por  ']
# -------------
# ['lento ,  ']
# -------------
# ['']
# -------------
# ['$3,50 esperaba  ']
# -------------
# ['ver  ']
# -------------
# ['uno  ']
# -------------
# ['bello  ']
# -------------
# ['detalle  ']
# -------------
# ['deber  ']
# -------------
# ['no  ']
# -------------
# ['malo  ']
# -------------
# ['bliss  ']
# -------------
# ['uno  ']
# -------------
# ['en  ']
# -------------
# ['promedio  ']
# -------------
# ['mas  ']
# -------------
# ['desilusionar  ']
# -------------
# ['en  ']
# -------------
# ['gran  ']
# -------------
# ['decepcionante . ']
# -------------
# ['bueno  ']
# -------------
# ['falta  ']
# -------------
# ['sky  ']
# -------------
# ['vacaciones  ']
# -------------
# ['caro  ']
# -------------
# ['especial ,  ']
# -------------
# ['hotel  ']
# -------------
# ['no  ']
# -------------
# ['en  ']
# -------------
# ['caro ,  ']
# -------------
# ['informar  ']
# -------------
# ['tan  ']
# -------------
# ['el  ']
# -------------
# ['hermoso  ']
# -------------
# ['parada  ']
# -------------
# ['muy  ']
# -------------
# ['grand  ']
# -------------
# ['uno  ']
# -------------
# ['decepcionante  ']
# -------------
# ['esperar  ']
# -------------
# ['tener  ']
# -------------
# ['no  ']
# -------------
# ['bueno  ']
# -------------
# ['adecuar ,  ']
# -------------
# ['cosa  ']
# -------------
# ['ambiente  ']
# -------------
# ['bueno  ']
# -------------
# ['decepcionar  ']
# -------------
# ['aceptable  ']
# -------------
# ['multipropiedad  ']
# -------------
# ['no  ']
# -------------
# ['maravilloso  ']
# -------------
# ['[??:??/11/??:????:??]  ']
# -------------
# ['3  ']
# -------------
# ['decepcionar !  ']
# -------------
# ['agradable  ']
# -------------
# ['comida  ']
# -------------
# ['bueno  ']
# -------------
# ['servicio  ']
# -------------
# ['realmente  ']
# -------------
# ['en  ']
# -------------
# ['entretener  ']
# -------------
# ['hard  ']
# -------------
# ['no  ']
# -------------
# ...
# -------------
# ['esperar  ']
# -------------
# ['ir  ']
# -------------
# ['¡ uno  ']
# -------------
# ['para  ']
# -------------
# ['romance  ']
# -------------
# ['no  ']
# -------------
# ['uno  ']
# -------------
# ['mejorable  ']
# -------------
# ['variedad  ']
# -------------
# ['valer  ']
# -------------
# ['visita  ']
# -------------
# ['haber  ']
# -------------
# ['nada  ']
# -------------
# ['punto  ']
# -------------
# ['uno  ']
# -------------
# ['decepcionar  ']
# -------------
# ['como  ']
# -------------
# ['parque  ']
# -------------
# ['lindo  ']
# -------------
# ['detalle  ']
# -------------
# ['normal  ']
# -------------
# ['uno  ']
# -------------
# ['este  ']
# -------------
# ['poco  ']
# -------------
# ['me  ']
# -------------
# ['especial  ']
# -------------
# ['visita  ']
# -------------
# ['poder  ']
# -------------
# ['¿ ya  ']
# -------------
# ['uno  ']
# -------------
# ['muy  ']
# -------------
# ['bonito  ']
# -------------
# ['estrecho  ']
# -------------
# ['afuera  ']
# -------------
# ['uno  ']
# -------------
# ['museo  ']
# -------------
# ['bueno  ']
# -------------
# ['lastimar  ']
# -------------
# ['experiencia  ']
# -------------
# ['bien  ']
# -------------
# ['regular  ']
# -------------
# ['lugar  ']
# -------------
# ['más  ']
# -------------
# ['deber  ']
# -------------
# ['demasiado  ']
# -------------
# ['obligar  ']
# -------------
# ['para  ']
# -------------
# ['el  ']
# -------------
# ['museo  ']
# -------------
# ['visita  ']
# -------------
# ['mucho  ']
# -------------
# ['obra  ']
# -------------
# ['sólo  ']
# -------------
# ['excelente  ']
# -------------
# ['interesante  ']
# -------------
# ['¡ hermoso  ']
# -------------
# ['tener  ']
# -------------
# ['uno  ']
# -------------
# ['guanajuato  ']
# -------------
# ['morbo  ']
# -------------
# ['muy  ']
# -------------
# ['algo  ']
# -------------
# ['sin  ']
# -------------
# ['bueno  ']
# -------------
# ['conocer  ']
# -------------
# ['lugar  ']
# -------------
# ['bueno  ']
# -------------
# ['poco  ']
# -------------
# ['impactante  ']
# -------------
# ['interesante  ']
# -------------
# ['ir  ']
# -------------
# ['para  ']
# -------------
# ['visita  ']
# -------------
# ['templo  ']
# -------------
# ['uno  ']
# -------------
# ['bueno  ']
# -------------
# ['esperar  ']
# -------------
# ['ser  ']
# -------------
# ['visita  ']
# -------------
# ['historia  ']
# -------------
# ['obligatorio  ']
# -------------
# ['para  ']
# -------------
# ['pequeño  ']
# -------------
# ['si  ']
# -------------
# ['decepción  ']
# -------------
# ['mucho  ']
# -------------
# ['famoso  ']
# -------------
# ['no  ']
# -------------
# ['pasa  ']
# -------------
# ['¡ bueno … !  ']
# -------------
# ['foto  ']
# -------------
# ['imagen  ']
# -------------
# ['el  ']
# -------------
# ['fila  ']
# -------------
# ['santo  ']
# -------------
# ['bonito  ']
# -------------
# ['ni  ']
# -------------
# ['']
# -------------
# ['sobrevaluar   sitio bello  ']
# -------------
# ['lugar  ']
# -------------
# ['curioso  ']
# -------------
# ['morbo  ']
# -------------
# ['sin  ']
# -------------
# ['para  ']
# -------------
# ['bello  ']
# -------------
# ['bueno  ']
# -------------
# ['más  ']
# -------------
# ['¡ momia !  ']
# -------------
# ['para  ']
# -------------
# ['nada  ']
# -------------
# ['arquitectura  ']
# -------------
# ['nada  ']
# -------------
# ['excelente  ']
# -------------
# ['prevenir  ']
# -------------
# ['nada  ']
# -------------
# ['demasiado  ']
# -------------
# ['este  ']
# -------------
# ['tener  ']
# -------------
# ['lugar  ']
# -------------
# ['visita  ']
# -------------
# ['bonito  ']
# -------------
# ['bueno  ']
# -------------
# ['']
# -------------
# ['mmm  bello  ']
# -------------
# ['estar  ']
# -------------
# ['mucho  ']
# -------------
# ['museo  ']
# -------------
# ['visita  ']
# -------------
# ['ser  ']
# -------------
# ['mezclar  ']
# -------------
# ['bonito  ']
# -------------
# ['no  ']
# -------------
# ['el  ']
# -------------
# ['sentimiento  ']
# -------------
# ['¡ historia !  ']
# -------------
# ['visita  ']
# -------------
# ['hermoso  ']
# -------------
# ['alhóndiga  ']
# -------------
# ['bueno  ']
# -------------
# ['momia  ']
# -------------
# ['ser  ']
# -------------
# ['excelente  ']
# -------------
# ['leyenda  ']
# -------------
# ['…  ']
# -------------
# ['poder  ']
# -------------
# ['el  ']
# -------------
# ['mercado  ']
# -------------
# ['interesante  ']
# -------------
# ['visitar  ']
# -------------
# ['uno  ']
# -------------
# ['clásico  ']
# -------------
# ['uno  ']
# -------------
# ['interesante  ']
# -------------
# ['escala  ']
# -------------
# ['visita  ']
# -------------
# ['de  ']
# -------------
# ['recomendable  ']
# -------------
# ['bonito  ']
# -------------
# ['horrible  ']
# -------------
# ['para  ']
# -------------
# ['callejón  ']
# -------------
# ['museo  ']
# -------------
# ['uno  ']
# -------------
# ['ok  ']
# -------------
# ['no  ']
# -------------
# ['bueno  ']
# -------------
# ['sin  ']
# -------------
# ['el  ']
# -------------
# ['pequeño ,  ']
# -------------
# ['bueno ,  ']
# -------------
# ['uno  ']
# -------------
# ['interesante  ']
# -------------
# ['beso  ']
# -------------
# ['vista  ']
# -------------
# ['no  ']
# -------------
# ['¡ ver ,  ']
# -------------
# ['no  ']
# -------------
# ['poder  ']
# -------------
# ['panorama  ']
# -------------
# ['sin  ']
# -------------
# ['indiferente  ']
# -------------
# ['fila  ']
# -------------
# ['para  ']
# -------------
# ['repleto  ']
# -------------
# ['bien  ']
# -------------
# ['porfiriano  ']
# -------------
# ['']
# -------------
# ['x uno  ']
# -------------
# ['imperdible  ']
# -------------
# ['grande  ']
# -------------
# ['aquí  ']
# -------------
# ['muy  ']
# -------------
# ['esperar  ']
# -------------
# ['muy  ']
# -------------
# ['muy  ']
# -------------
# ['lindo  ']
# -------------
# ['bueno  ']
# -------------
# ['gran  ']
# -------------
# ['bueno  ']
# -------------
# ['tradicional  ']
# -------------
# ['uno  ']
# -------------
# ['mi  ']
# -------------
# ['bien  ']
# -------------
# ['complemento  ']
# -------------
# ['¿ quién  ']
# -------------
# ['mercado  ']
# -------------
# ['tour  ']
# -------------
# ['para  ']
# -------------
# ['nada  ']
# -------------
# ['bello  ']
# -------------
# ['']
# -------------
# ['a ¡ desagradable !  ']
# -------------
# ['visita  ']
# -------------
# ['callejón  ']
# -------------
# ['igual  ']
# -------------
# ['guanajuato  ']
# -------------
# ['bueno  ']
# -------------
# ['sólo  ']
# -------------
# ['alhóndiga  ']
# -------------
# ['quitar  ']
# -------------
# ['el  ']
# -------------
# ['para  ']
# -------------
# ['regular  ']
# -------------
# ['invaluable  ']
# -------------
# ['uno  ']
# -------------
# ['si  ']
# -------------
# ['curioso  ']
# -------------
# ['descuidar  ']
# -------------
# ['bueno  ']
# -------------
# ['regular  ']
# -------------
# ['regular  ']
# -------------
# ['solia  ']
# -------------
# ['el  ']
# -------------
# ['caro  ']
# -------------
# ['solo  ']
# -------------
# ['no  ']
# -------------
# ['haber  ']
# -------------
# ['¡ haber  ']
# -------------
# ['bueno  ']
# -------------
# ['uno  ']
# -------------
# ['vista  ']
# -------------
# ['mercado  ']
# -------------
# ['bonito  ']
# -------------
# ['uno  ']
# -------------
# ['el  ']
# -------------
# ['mucho  ']
# -------------
# ['no  ']
# -------------
# ['momia  ']
# -------------
# ['mucho  ']
# -------------
# ['bonito  ']
# -------------
# ['imposible  ']
# -------------
# ['de  ']
# -------------
# ['algo  ']
# -------------
# ['mmmmmm  ']
# -------------
# ['el  ']
# -------------
# ['impresionante  ']
# -------------
# ['ir  ']
# -------------
# ['poder  ']
# -------------
# ['interesante  ']
# -------------
# ['cultura  ']
# -------------
# ['obra  ']
# -------------
# ['cansar  ']
# -------------
# ['sólo  ']
# -------------
# ['artesanía  ']
# -------------
# ['muy  ']
# -------------
# ['algo  ']
# -------------
# ['mucho  ']
# -------------
# ['vista  ']
# -------------
# ['mercadeo  ']
# -------------
# ['raro  ']
# -------------
# ['no  ']
# -------------
# ['el  ']
# -------------
# ['vista  ']
# -------------
# ['lugar  ']
# -------------
# ['uno  ']
# -------------
# ['muy  ']
# -------------
# ['para  ']
# -------------
# ['uno  ']
# -------------
# ['bonito  ']
# -------------
# ['uno  ']
# -------------
# ['vista  ']
# -------------
# ['muy  ']
# -------------
# ['decepcionante  ']
# -------------
# ['¡ entretener !  ']
# -------------
# ['estar  ']
# -------------
# ['visita  ']
# -------------
# ['impresionante  ']
# -------------
# ['interesante  ']
# -------------
# ['bonito  ']
# -------------
# ['romántico  ']
# -------------
# ['ser  ']
# -------------
# ['impresionante  ']
# -------------
# ['recuerdo  ']
# -------------
# ['no  ']
# -------------
# ['no  ']
# -------------
# ['¡ lindo !  ']
# -------------
# ['nada  ']
# -------------
# ['ser  ']
# -------------
# ['ida  ']
# -------------
# ['bueno  ']
# -------------
# ['no  ']
# -------------
# ['me  ']
# -------------
# ['dejar  ']
# -------------
# ['ser  ']
# -------------
# ['visitar  ']
# -------------
# ['interesante  ']
# -------------
# ['bonito  ']
# -------------
# ['angosto  ']
# -------------
# ['clásico  ']
# -------------
# ['poco  ']
# -------------
# ['el  ']
# -------------
# ['sitio  ']
# -------------
# ['romeo  ']
# -------------
# ['paseo  ']
# -------------
# ['excelente  ']
# -------------
# ['el  ']
# -------------
# ['bien  ']
# -------------
# ['visita  ']
# -------------
# ['poder  ']
# -------------
# ['visita  ']
# -------------
# ['en  ']
# -------------
# ['realismo  ']
# -------------
# ['gran  ']
# -------------
# ['bueno ,  ']
# -------------
# ['curiosiodad  ']
# -------------
# ['uno  ']
# -------------
# ['si  ']
# -------------
# ['bueno  ']
# -------------
# ['como  ']
# -------------
# ['si  ']
# -------------
# ['uno  ']
# -------------
# ['parte  ']
# -------------
# ['¡ más  ']
# -------------
# ['poco  ']
# -------------
# ['uno  ']
# -------------
# ['entretener  ']
# -------------
# ['museo  ']
# -------------
# ['opinión  ']
# -------------
# ['nos  ']
# -------------
# ['interesante  ']
# -------------
# ['el  ']
# -------------
# ['excelente  ']
# -------------
# ['mixed  ']
# -------------
# ['más  ']
# -------------
# ['magnífico  ']
# -------------
# ['ser  ']
# -------------
# ['sólo  ']
# -------------
# ['uno  ']
# -------------
# ['impactante  ']
# -------------
# ['el  ']
# -------------
# ['popular  ']
# -------------
# ['comida  ']
# -------------
# ['majestuoso  ']
# -------------
# ['bonito  ']
# -------------
# ['lugar  ']
# -------------
# ['descuido  ']
# -------------
# ['vista  ']
# -------------
# ['regular  ']
# -------------
# ['este  ']
# -------------
# ['obligatorio  ']
# -------------
# ['guanajuato  ']
# -------------
# ['cuerpo  ']
# -------------
# ['pasar  ']
# -------------
# ['poder  ']
# -------------
# ['uno  ']
# -------------
# ['cierto  ']
# -------------
# ['lugar  ']
# -------------
# ['bello  ']
# -------------
# ['lugar  ']
# -------------
# ['bonito  ']
# -------------
# ['bonito ,  ']
# -------------
# ['2  ']
# -------------
# ['visita  ']
# -------------
# ['museo  ']
# -------------
# ['¿ valer  ']
# -------------
# ['ya  ']
# -------------
# ['jardín  ']
# -------------
# ['macabro ,  ']
# -------------
# ['si  ']
# -------------
# ['muy  ']
# -------------
# ['uno  ']
# -------------
# ['no  ']
# -------------
# ['haber  ']
# -------------
# ['sin  ']
# -------------
# ['llegar  ']
# -------------
# ['para  ']
# -------------
# ['no  ']
# -------------
# ['simple  ']
# -------------
# ['lindo  ']
# -------------
# ['mucho  ']
# -------------
# ['potencial  ']
# -------------
# ['uno  ']
# -------------
# ['falta  ']
# -------------
# ['muy  ']
# -------------
# ['si  ']
# -------------
# ['sólo  ']
# -------------
# ['bueno  ']
# -------------
# ['nada  ']
# -------------
# ['esperar  ']
# -------------
# ['macabro …  ']
# -------------
# ['si  ']
# -------------
# ['gente ,  ']
# -------------
# ['uno  ']
# -------------
# ['remodelar  ']
# -------------
# ['falta  ']
# -------------
# ['ser  ']
# -------------
# ['tradicional  ']
# -------------
# ['concurrir  ']
# -------------
# ['story  ']
# -------------
# ['mercado  ']
# -------------
# ['escalofríante  ']
# -------------
# ['el  ']
# -------------
# ['falta  ']
# -------------
# ['sin  ']
# -------------
# ['aunque  ']
# -------------
# ['mucho  ']
# -------------
# ['historia  ']
# -------------
# ['no  ']
# -------------
# ['típico  ']
# -------------
# ['nada  ']
# -------------
# ['vivo  ']
# -------------
# ['escalera  ']
# -------------
# ['nada  ']
# -------------
# ['le  ']
# -------------
# ['uno  ']
# -------------
# ['planta  ']
# -------------
# ['ser  ']
# -------------
# ['impactante  ']
# -------------
# ['guanajuato  ']
# -------------
# ['interesante  ']
# -------------
# ['museo  ']
# -------------
# ['uno  ']
# -------------
# ['historia  ']
# -------------
# ['interesante  ']
# -------------
# ['colorir  ']
# -------------
# ['exceso  ']
# -------------
# ['no  ']
# -------------
# ['uno  ']
# -------------
# ['regular  ']
# -------------
# ['visita  ']
# -------------
# ['visita  ']
# -------------
# ['poco  ']
# -------------
# ['no  ']
# -------------
# ['bonito  ']
# -------------
# ['museo  ']
# -------------
# ['ser  ']
# -------------
# ['uno  ']
# -------------
# ['nada  ']
# -------------
# ['opinar  ']
# -------------
# ['¡ totalmente  ']
# -------------
# ['lindo  ']
# -------------
# ['100nochesfueradecasa  ']
# -------------
# ['excelente  ']
# -------------
# ['para  ']
# -------------
# ['interesante  ']
# -------------
# ['atracción  ']
# -------------
# ['guía  ']
# -------------
# ['no  ']
# -------------
# ['solo  ']
# -------------
# ['uno  ']
# -------------
# ['nada  ']
# -------------
# ['punto  ']
# -------------
# ['genial  ']
# -------------
# ['no  ']
# -------------
# ['poder  ']
# -------------
# ['mmmm …  ']
# -------------
# ['no  ']
# -------------
# ['museo  ']
# -------------
# ['bien ,  ']
# -------------
# ['el  ']
# -------------
# ['interesante  ']
# -------------
# ['mercado  ']
# -------------
# ['lugar  ']
# -------------
# ['uno  ']
# -------------
# ['¡ interesante  ']
# -------------
# ['']
# -------------
# ['a uno  ']
# -------------
# ['mucho  ']
# -------------
# ['no  ']
# -------------
# ['visita  ']
# -------------
# ['interesante  ']
# -------------
# ['bien  ']
# -------------
# ['demasiado  ']
# -------------
# ['bonito ,  ']
# -------------
# ['muy  ']
# -------------
# ['mucho  ']
# -------------
# ['maloliente  ']
# -------------
# ['largo  ']
# -------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/vaps/Descargas/Freeling/Generar_Corpus.ipynb Cell 3' in <cell line: 1>()
#       <a href='vscode-notebook-cell:/home/vaps/Descargas/Freeling/Generar_Corpus.ipynb#ch0000002?line=8'>9</a> 	else:
#      <a href='vscode-notebook-cell:/home/vaps/Descargas/Freeling/Generar_Corpus.ipynb#ch0000002?line=9'>10</a>             for linea in range(len(corpus)):
# ---> <a href='vscode-notebook-cell:/home/vaps/Descargas/Freeling/Generar_Corpus.ipynb#ch0000002?line=10'>11</a>                 corpus_lematizado.append(load_corpus(str(corpus.loc[linea]["Title"]) + " " + str(corpus.loc[linea]["Opinion"])))
#      <a href='vscode-notebook-cell:/home/vaps/Descargas/Freeling/Generar_Corpus.ipynb#ch0000002?line=11'>12</a>                 print("-------------")
#      <a href='vscode-notebook-cell:/home/vaps/Descargas/Freeling/Generar_Corpus.ipynb#ch0000002?line=12'>13</a>             corpus_file = open('corpus_lematizado.pkl','wb')
#
# /home/vaps/Descargas/Freeling/Generar_Corpus.ipynb Cell 2' in load_corpus(corpus)
#       <a href='vscode-notebook-cell:/home/vaps/Descargas/Freeling/Generar_Corpus.ipynb#ch0000001?line=3'>4</a> corpus = corpus.replace('(','').replace(')','')
#       <a href='vscode-notebook-cell:/home/vaps/Descargas/Freeling/Generar_Corpus.ipynb#ch0000001?line=5'>6</a> for linea in corpus.split():
# ----> <a href='vscode-notebook-cell:/home/vaps/Descargas/Freeling/Generar_Corpus.ipynb#ch0000001?line=6'>7</a>     corpus_lematizado.append(lematizar(linea))
#       <a href='vscode-notebook-cell:/home/vaps/Descargas/Freeling/Generar_Corpus.ipynb#ch0000001?line=7'>8</a>     print(corpus_lematizado)
#       <a href='vscode-notebook-cell:/home/vaps/Descargas/Freeling/Generar_Corpus.ipynb#ch0000001?line=8'>9</a>     return(corpus_lematizado)
#
# File ~/Descargas/Freeling/Preprocesamiento/lematizador.py:70, in lematizar(linea)
#      <a href='file:///home/vaps/Descargas/Freeling/Preprocesamiento/lematizador.py?line=66'>67</a> 	linea = linea + "."
#      <a href='file:///home/vaps/Descargas/Freeling/Preprocesamiento/lematizador.py?line=67'>68</a> 	punto_agregado = True
# ---> <a href='file:///home/vaps/Descargas/Freeling/Preprocesamiento/lematizador.py?line=69'>70</a> palabras = tk.tokenize(linea)
#      <a href='file:///home/vaps/Descargas/Freeling/Preprocesamiento/lematizador.py?line=70'>71</a> ls = sp.split(sid,palabras,False)
#      <a href='file:///home/vaps/Descargas/Freeling/Preprocesamiento/lematizador.py?line=71'>72</a> ls = mf.analyze(ls)
#
# File ~/Descargas/Freeling/Preprocesamiento/utilidades/pyfreeling.py:4762, in tokenizer.tokenize(self, *args)
#    <a href='file:///home/vaps/Descargas/Freeling/Preprocesamiento/utilidades/pyfreeling.py?line=4760'>4761</a> def tokenize(self, *args) -> "void":
# -> <a href='file:///home/vaps/Descargas/Freeling/Preprocesamiento/utilidades/pyfreeling.py?line=4761'>4762</a>     return _pyfreeling.tokenizer_tokenize(self, *args)
#
# KeyboardInterrupt:
